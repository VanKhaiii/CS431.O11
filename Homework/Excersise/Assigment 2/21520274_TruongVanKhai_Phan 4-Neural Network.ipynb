# %% [markdown]
# # MODULE CS431 - CÁC KỸ THUẬT HỌC SÂU VÀ ỨNG DỤNG
#
# **Hướng dẫn**:
# - Khởi động kernel: Ở thanh menu, chọn Kernel$\rightarrow$Restart kernel.
# - Hoàn tất tất cả các mục có comment `YOUR CODE HERE`
# - Chạy toàn bộ các block code để kiểm tra: Ở thanh menu, chọn Cell$\rightarrow$Run All.

# %% [markdown]
# ---

# %% [markdown]
# # CÀI ĐẶT MÔ HÌNH NEURAL NETWORK VỚI KERAS

# %% [markdown]
# Một mô hình máy học cần có đủ ít nhất 7 phương thức sau:
# - `__init__`: hàm constructor trong hướng đối tượng, được sử dụng để khởi tạo các tham số mặc định hoặc tham số bắt đầu một mô hình. Trong những bài tập đầu tiên, để đơn giản constructor sẽ không sử dụng.
# - `build`: xây dựng kiến trúc của mô hình
# - `train`: bắt đầu quá trình huấn luyện mô hình
# - `save`: lưu lại mô hình sau khi đã huấn luyện
# - `load`: load lên mô hình từ file đã huấn luyện (pretrained)
# - `summary`: in tóm tắt kiến trúc mô hình
# - `predict`: dự đoán giá trị output từ dữ liệu đầu vào

# %%
# Mô hình cài đặt tổng quát bao gồm 7 phương thức cơ bản
# Lưu ý: mô hình này chỉ mang tính gợi ý, không bắt buộc
# Tuy nhiên, trong phần bài tập cần tuân theo các tên phương thức này
class MyModel:
    # constructor
    def __init__(self):
        return None
  
    # Implement architecture of the model
    def build(self):
        return None

    # Train the defined model with training and validation data 
    def train(self):
        return None

    # Save the trained model to file
    def save(self, model_path):
        return None

    # Load pretrained model from file
    def load(self):
        return None
    # Visualize your model
    def summary(self):
        return None

    # Apply your model with new input data
    def predict(self):
        return None

# %% [markdown]
# ## 1. Import các thư viện Keras
#
# Đầu tiên, ta sẽ import các thư viện, module, hàm của `Keras`:
# - `Input`: để nhận dữ liệu đầu vào cho mô hình
# - `Dense`: hay còn gọi là lớp Fully Connected (Lớp kết nối đầy đủ), một thành phần quan trọng của các mô hình dựa trên mạng Neural Network.
# - `Model`: đây là lớp đối tượng mô hình được sử dụng để đóng gói lớp đầu vào, đầu ra, sau đó huấn luyện với phương thức `fit` và dự đoán kết quả với `predict`.
# - `load_model`: hàm sử dụng để load mô hình lên từ file

# %%
from keras.layers import Input, Dense
from keras import Model
import tensorflow as tf
from keras.models import load_model
import numpy as np

# %% [markdown]
# ## 2. Cài đặt mô hình Neural Network
# Tiếp theo, ta sẽ dựa trên khung đối tượng `MyModel` đã trình bày ở mục trước để tiến hành cài đặt mô hình **Neural Network**. Phương thức chính mà bài tập này cần thực hiện là `def build()`. Các phương thức còn lại đã được cài đặt sẵn, các bạn cần đọc, hiểu ý nghĩa và cách thức sử dụng về sau.
#
# <p align="center">
#   <img src="NeuralNet.png" />
# </p>

# %%
# Neural Network
class NeuralNetwork:
    def __init__(self): # Self is similar to your 'this' pointer in C++
        return None

    def build(self, input_dim, output_dim, n_hidden, n_neurons):
        # `input_dim`: kích thước input feature
        # `output_dim`: số phân lớp cần phân loại
        # `n_hidden`: số lượng lớp ẩn
        # `n_neurons`: số lượng neuron mỗi lớp ẩn
        
        # Khởi tạo model
        self.model = None
        
        # Hãy cài đặt để định nghĩa KIẾN TRÚC MÔ HÌNH và lưu ở thuộc tính `self.model`
        # với các biến đối tượng sau:
        #  - tạo biến `input` với lớp đối tượng `Input` của Keras, 
        #    truyền vào kích thước đầu vào `input_dim`
        #  - tạo `n_hidden`lớp ẩn biết rằng, mỗi lớp ẩn có `n_neurons`, có sử dụng bias
        #    activation là hàm `sigmoid`. Đầu ra của lớp ẩn này là đầu vào lớp ẩn sau.
        #  - tạo biến `output` với lớp đối tượng `Dense` của Keras,
        #    truyền vào các tham số:  kích thước output (chú ý PHÂN LOẠI ĐA LỚP),
        #    có sử dụng bias, CÓ SỬ DỤNG hàm activation là `softmax`. Đầu vào của lớp
        #    output chính là lớp ẩn cuối cùng.
        # Sau bước này, self.model sẽ đóng gói 2 biến `input` và `output` để tạo thành mô hình
        # YOUR CODE HERE
        input = Input(shape=(input_dim,))
        
        #hidden layer
        x = input 
        for _ in range(n_hidden):
            x = Dense(n_neurons, use_bias=True, activation='sigmoid')(x)
            
        output = Dense(output_dim, use_bias=True, activation='softmax')(x)
        
        self.model = Model(input, output)
        return self.model

    def train(self, x_train, y_train, epochs=500):
        # Khởi tạo mặc định với số `epochs=50`, `learning_rate=0.05`
        opt = tf.keras.optimizers.SGD(learning_rate=0.05) # Stochastic Gradient Descent
        self.model.compile(optimizer=opt, loss='categorical_crossentropy') # CCE loss
        return self.model.fit(x_train, y_train, epochs=epochs)

    def save(self, model_file):
        return self.model.save(model_file)
  
    def load(self, model_file):
        self.model = load_model(model_file)

    def summary(self):
        self.model.summary()

    def predict(self, x_test):
        return self.model.predict(x_test)
  
    def get_weights(self, layer_id):
        return self.model.layers[layer_id].get_weights()

# %% [markdown]
# Tiếp theo, ta sẽ khởi tạo đối tượng NeuralNetwork và kiểm tra thử xem phương `build` đã cài đặt chính xác chưa.

# %%
nn = NeuralNetwork()
# Trong ví dụ này, ta sẽ khởi tạo input là một vector 1000 chiều, 
# bài toán cần phân loại 20 lớp đối tượng. Số lượng lớp ẩn là 3 
# và số neuron mỗi lớp ẩn là  10.
nn.build(1000, 20, 3, 10)

# %%
# Kiểm tra sơ bộ kiến trúc mạng gồm 2 + 3 = 5 lớp: Input, 3 lớp ẩn và Output
assert len(nn.model.layers)==5
assert str(type(nn.model.layers[0])).endswith("input_layer.InputLayer'>") == True
assert str(type(nn.model.layers[1])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[2])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[3])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[4])).endswith("core.dense.Dense'>") == True
assert nn.model.layers[0].input_shape[0][1] == 1000
assert nn.model.layers[-1].output_shape[1] == 20
assert nn.model.layers[1].use_bias == True

# %%
# Kiểm tra với bộ test ẩn

# %% [markdown]
# ## 3. Tạo dữ liệu mẫu (toy example)
# Bước tiếp theo, ta sẽ tiến hành tạo mẫu dữ liệu để huấn luyện và kiểm thử.
#
# Dữ liệu được tạo ra là các điểm rải ngẫu nhiên xung quanh 4 cụm điểm:
# - [10, -2]
# - [2, 8]
# - [12, 8]
# - [-2, 0]
#
# Lưu ý rằng, 4 cụm điểm này rời nhau đủ xa để khi thêm nhiễu ngẫu nhiên,
# các điểm thuộc 4 cụm này vẫn không giao thoa nhau.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Số phân lớp: 4
K = 4
# Tạo bộ dữ  liệu gồm 4 điểm
# S1, S2, S3, S4 là tâm của 4 lớp
S1= np.array([[10,-2]])
S2= np.array([[2,8]])
S3= np.array([[12,8]])
S4= np.array([[-2,0]])

# 50 samples mỗi lớp
n_sample = 50
# Phát sinh các điểm với nhiễu ngẫu nhiên xung quanh 4 tâm
pts1 = S1 + np.random.normal(0, 1.5, size=(n_sample,2))
pts2 = S2 + np.random.normal(0, 1.5, size=(n_sample,2))
pts3 = S3 + np.random.normal(0, 1.5, size=(n_sample,2))
pts4 = S4 + np.random.normal(0, 1.5, size=(n_sample,2))

# Nối tất cả các mẫu thành một khối dữ liệu X (input feature) và Y (nhãn)
X_train = np.concatenate((pts1, pts2, pts3, pts4))
# Concatenate data labels to a single input variable Y
Y_train = np.concatenate(([0]*n_sample, [1]*n_sample, [2]*n_sample, [3]*n_sample))

# Chuyển Y từ dạng nhãn sang one-hot vector
Y_train = Y_train.astype(int)
Y_oh = np.zeros((Y_train.size, Y_train.max()+1 ))
Y_oh[np.arange(Y_train.size), Y_train] = 1

# Trực quan hóa dữ liệu bằng các hình tròn màu đỏ, xanh lá, xanh dương và vàng
plt.plot(pts1[:,0], pts1[:,1], 'ro')
plt.plot(pts2[:,0], pts2[:,1], 'go')
plt.plot(pts3[:,0], pts3[:,1], 'bo')
plt.plot(pts4[:,0], pts4[:,1], 'yo')
plt.show()

print(X_train.shape, "  ", Y_train.shape)
# Out:
# (200, 2)    (200,)

# %% [markdown]
# ## 4. Huấn luyện mô hình với dữ liệu mẫu
#
# Tiếp theo, ta sẽ khởi tạo lại mô hình để phù hợp với dữ liệu mẫu đã phát sinh ở bước trước. Việc xây dựng kiến trúc của mô hình phải phù hợp với số chiều của dữ liệu mẫu.

# %%
nn = NeuralNetwork()

# Hãy gọi phương thức `build` cho đối tượng `sr` và truyền tham số đầu vào
# tương ứng với dữ liệu train đã phát sinh ở code block trên
# Theo bạn, `input_dim`, `output_dim` bằng bao nhiêu?
# Đối với các lớp ẩn, ta khởi tạo 01 lớp ẩn và 03 neuron cho mỗi lớp ẩn

# YOUR CODE HERE
input_dim = 2
output_dim = 4
n_hidden, n_neurons = 1, 3
nn.build(input_dim, output_dim, n_hidden, n_neurons)

# Để hiển thị kiến trúc của mô hình ta gọi phương thức `summary`
print("Kiến trúc của mô hình Neural Network: ")
nn.summary()
# Out:
# Kiến trúc của mô hình Neural Network:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 3)                 9
#
#  dense_5 (Dense)             (None, 4)                 16
#
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Kiểm tra kết quả khi đối tượng `nn` gọi phương thức `build`

# %%
# Để huấn luyện mô hình ta gọi phương thức `train` với dữ liệu mẫu đã tạo được
# Nếu bước `build` mô hình gọi đúng thì bước `train` sau sẽ thực hiện thành công
# LƯU Ý: Ở đây ta sử dụng output là Y_oh dạng one-hot thay vì dạng nhãn (label)
hist = nn.train(X_train, Y_oh)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2796
# Epoch 2/500
# 7/7 [==============================] - 0s 858us/step - loss: 1.2544
# Epoch 3/500
# 7/7 [==============================] - 0s 667us/step - loss: 1.2349
# Epoch 4/500
# 7/7 [==============================] - 0s 660us/step - loss: 1.2164
# Epoch 5/500
# 7/7 [==============================] - 0s 667us/step - loss: 1.2007
# Epoch 6/500
# 7/7 [==============================] - 0s 855us/step - loss: 1.1859
# Epoch 7/500
# 7/7 [==============================] - 0s 666us/step - loss: 1.1726
# Epoch 8/500
# 7/7 [==============================] - 0s 861us/step - loss: 1.1597
# Epoch 9/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1472
# Epoch 10/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1344
# Epoch 11/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1213
# Epoch 12/500
# 7/7 [==============================] - 0s 837us/step - loss: 1.1086
# Epoch 13/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0954
# Epoch 14/500
# 7/7 [==============================] - 0s 833us/step - loss: 1.0819
# Epoch 15/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0672
# Epoch 16/500
# 7/7 [==============================] - 0s 918us/step - loss: 1.0519
# Epoch 17/500
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0368
# Epoch 18/500
# 7/7 [==============================] - 0s 833us/step - loss: 1.0213
# Epoch 19/500
# 7/7 [==============================] - 0s 766us/step - loss: 1.0067
# Epoch 20/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.9911
# Epoch 21/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.9766
# Epoch 22/500
# 7/7 [==============================] - 0s 823us/step - loss: 0.9625
# Epoch 23/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.9491
# Epoch 24/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.9350
# Epoch 25/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9223
# Epoch 26/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9104
# Epoch 27/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.8984
# Epoch 28/500
# 7/7 [==============================] - 0s 999us/step - loss: 0.8869
# Epoch 29/500
# 7/7 [==============================] - 0s 804us/step - loss: 0.8757
# Epoch 30/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8647
# Epoch 31/500
# 7/7 [==============================] - 0s 917us/step - loss: 0.8546
# Epoch 32/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.8445
# Epoch 33/500
# 7/7 [==============================] - 0s 499us/step - loss: 0.8346
# Epoch 34/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.8247
# Epoch 35/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.8156
# Epoch 36/500
# 7/7 [==============================] - 0s 751us/step - loss: 0.8065
# Epoch 37/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.7977
# Epoch 38/500
# 7/7 [==============================] - 0s 775us/step - loss: 0.7893
# Epoch 39/500
# 7/7 [==============================] - 0s 665us/step - loss: 0.7808
# Epoch 40/500
# 7/7 [==============================] - 0s 672us/step - loss: 0.7726
# Epoch 41/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.7649
# Epoch 42/500
# 7/7 [==============================] - 0s 768us/step - loss: 0.7570
# Epoch 43/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.7494
# Epoch 44/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.7418
# Epoch 45/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.7350
# Epoch 46/500
# 7/7 [==============================] - 0s 985us/step - loss: 0.7278
# Epoch 47/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.7210
# Epoch 48/500
# 7/7 [==============================] - 0s 965us/step - loss: 0.7139
# Epoch 49/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.7069
# Epoch 50/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.7001
# Epoch 51/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.6935
# Epoch 52/500
# 7/7 [==============================] - 0s 841us/step - loss: 0.6865
# Epoch 53/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.6799
# Epoch 54/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.6731
# Epoch 55/500
# 7/7 [==============================] - 0s 838us/step - loss: 0.6663
# Epoch 56/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.6594
# Epoch 57/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.6524
# Epoch 58/500
# 7/7 [==============================] - 0s 785us/step - loss: 0.6452
# Epoch 59/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.6382
# Epoch 60/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.6308
# Epoch 61/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.6232
# Epoch 62/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6156
# Epoch 63/500
# 7/7 [==============================] - 0s 653us/step - loss: 0.6079
# Epoch 64/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.5997
# Epoch 65/500
# 7/7 [==============================] - 0s 884us/step - loss: 0.5916
# Epoch 66/500
# 7/7 [==============================] - 0s 838us/step - loss: 0.5833
# Epoch 67/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5751
# Epoch 68/500
# 7/7 [==============================] - 0s 673us/step - loss: 0.5669
# Epoch 69/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.5591
# Epoch 70/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5513
# Epoch 71/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.5433
# Epoch 72/500
# 7/7 [==============================] - 0s 999us/step - loss: 0.5354
# Epoch 73/500
# 7/7 [==============================] - 0s 908us/step - loss: 0.5277
# Epoch 74/500
# 7/7 [==============================] - 0s 837us/step - loss: 0.5202
# Epoch 75/500
# 7/7 [==============================] - 0s 999us/step - loss: 0.5122
# Epoch 76/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.5051
# Epoch 77/500
# 7/7 [==============================] - 0s 876us/step - loss: 0.4981
# Epoch 78/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.4914
# Epoch 79/500
# 7/7 [==============================] - 0s 866us/step - loss: 0.4844
# Epoch 80/500
# 7/7 [==============================] - 0s 810us/step - loss: 0.4778
# Epoch 81/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.4713
# Epoch 82/500
# 7/7 [==============================] - 0s 749us/step - loss: 0.4650
# Epoch 83/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.4586
# Epoch 84/500
# 7/7 [==============================] - 0s 749us/step - loss: 0.4527
# Epoch 85/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.4467
# Epoch 86/500
# 7/7 [==============================] - 0s 751us/step - loss: 0.4406
# Epoch 87/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.4352
# Epoch 88/500
# 7/7 [==============================] - 0s 746us/step - loss: 0.4295
# Epoch 89/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.4238
# Epoch 90/500
# 7/7 [==============================] - 0s 585us/step - loss: 0.4185
# Epoch 91/500
# 7/7 [==============================] - 0s 500us/step - loss: 0.4132
# Epoch 92/500
# 7/7 [==============================] - 0s 671us/step - loss: 0.4080
# Epoch 93/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.4027
# Epoch 94/500
# 7/7 [==============================] - 0s 754us/step - loss: 0.3976
# Epoch 95/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.3927
# Epoch 96/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3878
# Epoch 97/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3833
# Epoch 98/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.3789
# Epoch 99/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.3743
# Epoch 100/500
# 7/7 [==============================] - 0s 764us/step - loss: 0.3699
# Epoch 101/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3657
# Epoch 102/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3614
# Epoch 103/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3572
# Epoch 104/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3530
# Epoch 105/500
# 7/7 [==============================] - 0s 922us/step - loss: 0.3489
# Epoch 106/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.3448
# Epoch 107/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.3409
# Epoch 108/500
# 7/7 [==============================] - 0s 785us/step - loss: 0.3373
# Epoch 109/500
# 7/7 [==============================] - 0s 837us/step - loss: 0.3336
# Epoch 110/500
# 7/7 [==============================] - 0s 673us/step - loss: 0.3299
# Epoch 111/500
# 7/7 [==============================] - 0s 676us/step - loss: 0.3265
# Epoch 112/500
# 7/7 [==============================] - 0s 868us/step - loss: 0.3226
# Epoch 113/500
# 7/7 [==============================] - 0s 749us/step - loss: 0.3192
# Epoch 114/500
# 7/7 [==============================] - 0s 708us/step - loss: 0.3157
# Epoch 115/500
# 7/7 [==============================] - 0s 757us/step - loss: 0.3124
# Epoch 116/500
# 7/7 [==============================] - 0s 841us/step - loss: 0.3090
# Epoch 117/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.3058
# Epoch 118/500
# 7/7 [==============================] - 0s 751us/step - loss: 0.3028
# Epoch 119/500
# 7/7 [==============================] - 0s 854us/step - loss: 0.2995
# Epoch 120/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.2966
# Epoch 121/500
# 7/7 [==============================] - 0s 682us/step - loss: 0.2935
# Epoch 122/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.2905
# Epoch 123/500
# 7/7 [==============================] - 0s 878us/step - loss: 0.2877
# Epoch 124/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.2848
# Epoch 125/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2819
# Epoch 126/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.2792
# Epoch 127/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.2767
# Epoch 128/500
# 7/7 [==============================] - 0s 832us/step - loss: 0.2739
# Epoch 129/500
# 7/7 [==============================] - 0s 941us/step - loss: 0.2715
# Epoch 130/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2686
# Epoch 131/500
# 7/7 [==============================] - 0s 854us/step - loss: 0.2661
# Epoch 132/500
# 7/7 [==============================] - 0s 988us/step - loss: 0.2636
# Epoch 133/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.2612
# Epoch 134/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.2587
# Epoch 135/500
# 7/7 [==============================] - 0s 852us/step - loss: 0.2564
# Epoch 136/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.2541
# Epoch 137/500
# 7/7 [==============================] - 0s 758us/step - loss: 0.2518
# Epoch 138/500
# 7/7 [==============================] - 0s 938us/step - loss: 0.2495
# Epoch 139/500
# 7/7 [==============================] - 0s 729us/step - loss: 0.2474
# Epoch 140/500
# 7/7 [==============================] - 0s 903us/step - loss: 0.2452
# Epoch 141/500
# 7/7 [==============================] - 0s 979us/step - loss: 0.2431
# Epoch 142/500
# 7/7 [==============================] - 0s 805us/step - loss: 0.2410
# Epoch 143/500
# 7/7 [==============================] - 0s 937us/step - loss: 0.2389
# Epoch 144/500
# 7/7 [==============================] - 0s 838us/step - loss: 0.2368
# Epoch 145/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.2349
# Epoch 146/500
# 7/7 [==============================] - 0s 949us/step - loss: 0.2329
# Epoch 147/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.2308
# Epoch 148/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.2290
# Epoch 149/500
# 7/7 [==============================] - 0s 584us/step - loss: 0.2270
# Epoch 150/500
# 7/7 [==============================] - 0s 687us/step - loss: 0.2250
# Epoch 151/500
# 7/7 [==============================] - 0s 710us/step - loss: 0.2232
# Epoch 152/500
# 7/7 [==============================] - 0s 760us/step - loss: 0.2213
# Epoch 153/500
# 7/7 [==============================] - 0s 801us/step - loss: 0.2196
# Epoch 154/500
# 7/7 [==============================] - 0s 760us/step - loss: 0.2177
# Epoch 155/500
# 7/7 [==============================] - 0s 676us/step - loss: 0.2159
# Epoch 156/500
# 7/7 [==============================] - 0s 747us/step - loss: 0.2142
# Epoch 157/500
# 7/7 [==============================] - 0s 809us/step - loss: 0.2125
# Epoch 158/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.2109
# Epoch 159/500
# 7/7 [==============================] - 0s 751us/step - loss: 0.2093
# Epoch 160/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.2076
# Epoch 161/500
# 7/7 [==============================] - 0s 922us/step - loss: 0.2059
# Epoch 162/500
# 7/7 [==============================] - 0s 937us/step - loss: 0.2043
# Epoch 163/500
# 7/7 [==============================] - 0s 832us/step - loss: 0.2027
# Epoch 164/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.2013
# Epoch 165/500
# 7/7 [==============================] - 0s 755us/step - loss: 0.1997
# Epoch 166/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1982
# Epoch 167/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1968
# Epoch 168/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1954
# Epoch 169/500
# 7/7 [==============================] - 0s 840us/step - loss: 0.1940
# Epoch 170/500
# 7/7 [==============================] - 0s 896us/step - loss: 0.1924
# Epoch 171/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1911
# Epoch 172/500
# 7/7 [==============================] - 0s 848us/step - loss: 0.1896
# Epoch 173/500
# 7/7 [==============================] - 0s 966us/step - loss: 0.1882
# Epoch 174/500
# 7/7 [==============================] - 0s 979us/step - loss: 0.1869
# Epoch 175/500
# 7/7 [==============================] - 0s 908us/step - loss: 0.1856
# Epoch 176/500
# 7/7 [==============================] - 0s 882us/step - loss: 0.1843
# Epoch 177/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1829
# Epoch 178/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1817
# Epoch 179/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1804
# Epoch 180/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1791
# Epoch 181/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1778
# Epoch 182/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.1767
# Epoch 183/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1755
# Epoch 184/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1743
# Epoch 185/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1731
# Epoch 186/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1720
# Epoch 187/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1707
# Epoch 188/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1696
# Epoch 189/500
# 7/7 [==============================] - 0s 898us/step - loss: 0.1686
# Epoch 190/500
# 7/7 [==============================] - 0s 917us/step - loss: 0.1674
# Epoch 191/500
# 7/7 [==============================] - 0s 832us/step - loss: 0.1664
# Epoch 192/500
# 7/7 [==============================] - 0s 831us/step - loss: 0.1653
# Epoch 193/500
# 7/7 [==============================] - 0s 920us/step - loss: 0.1642
# Epoch 194/500
# 7/7 [==============================] - 0s 703us/step - loss: 0.1631
# Epoch 195/500
# 7/7 [==============================] - 0s 776us/step - loss: 0.1621
# Epoch 196/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1611
# Epoch 197/500
# 7/7 [==============================] - 0s 681us/step - loss: 0.1601
# Epoch 198/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1591
# Epoch 199/500
# 7/7 [==============================] - 0s 578us/step - loss: 0.1581
# Epoch 200/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1571
# Epoch 201/500
# 7/7 [==============================] - 0s 836us/step - loss: 0.1561
# Epoch 202/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1552
# Epoch 203/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1543
# Epoch 204/500
# 7/7 [==============================] - 0s 835us/step - loss: 0.1532
# Epoch 205/500
# 7/7 [==============================] - 0s 668us/step - loss: 0.1523
# Epoch 206/500
# 7/7 [==============================] - 0s 839us/step - loss: 0.1513
# Epoch 207/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1504
# Epoch 208/500
# 7/7 [==============================] - 0s 786us/step - loss: 0.1496
# Epoch 209/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1487
# Epoch 210/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1478
# Epoch 211/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1470
# Epoch 212/500
# 7/7 [==============================] - 0s 681us/step - loss: 0.1461
# Epoch 213/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1452
# Epoch 214/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1444
# Epoch 215/500
# 7/7 [==============================] - 0s 751us/step - loss: 0.1436
# Epoch 216/500
# 7/7 [==============================] - 0s 835us/step - loss: 0.1427
# Epoch 217/500
# 7/7 [==============================] - 0s 660us/step - loss: 0.1419
# Epoch 218/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1412
# Epoch 219/500
# 7/7 [==============================] - 0s 586us/step - loss: 0.1402
# Epoch 220/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1395
# Epoch 221/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1387
# Epoch 222/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1380
# Epoch 223/500
# 7/7 [==============================] - 0s 850us/step - loss: 0.1372
# Epoch 224/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1363
# Epoch 225/500
# 7/7 [==============================] - 0s 894us/step - loss: 0.1356
# Epoch 226/500
# 7/7 [==============================] - 0s 845us/step - loss: 0.1349
# Epoch 227/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1341
# Epoch 228/500
# 7/7 [==============================] - 0s 804us/step - loss: 0.1334
# Epoch 229/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1327
# Epoch 230/500
# 7/7 [==============================] - 0s 742us/step - loss: 0.1319
# Epoch 231/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1312
# Epoch 232/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1306
# Epoch 233/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1299
# Epoch 234/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1292
# Epoch 235/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1285
# Epoch 236/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1278
# Epoch 237/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1271
# Epoch 238/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.1264
# Epoch 239/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1258
# Epoch 240/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1252
# Epoch 241/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1245
# Epoch 242/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1239
# Epoch 243/500
# 7/7 [==============================] - 0s 722us/step - loss: 0.1232
# Epoch 244/500
# 7/7 [==============================] - 0s 930us/step - loss: 0.1226
# Epoch 245/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1220
# Epoch 246/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1214
# Epoch 247/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1207
# Epoch 248/500
# 7/7 [==============================] - 0s 744us/step - loss: 0.1202
# Epoch 249/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1196
# Epoch 250/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1190
# Epoch 251/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1183
# Epoch 252/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1178
# Epoch 253/500
# 7/7 [==============================] - 0s 828us/step - loss: 0.1173
# Epoch 254/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1166
# Epoch 255/500
# 7/7 [==============================] - 0s 610us/step - loss: 0.1161
# Epoch 256/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1155
# Epoch 257/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1149
# Epoch 258/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1144
# Epoch 259/500
# 7/7 [==============================] - 0s 664us/step - loss: 0.1139
# Epoch 260/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1133
# Epoch 261/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.1128
# Epoch 262/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1122
# Epoch 263/500
# 7/7 [==============================] - 0s 775us/step - loss: 0.1117
# Epoch 264/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1111
# Epoch 265/500
# 7/7 [==============================] - 0s 720us/step - loss: 0.1106
# Epoch 266/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.1101
# Epoch 267/500
# 7/7 [==============================] - 0s 931us/step - loss: 0.1096
# Epoch 268/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1091
# Epoch 269/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1086
# Epoch 270/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.1082
# Epoch 271/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1076
# Epoch 272/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1072
# Epoch 273/500
# 7/7 [==============================] - 0s 908us/step - loss: 0.1067
# Epoch 274/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1062
# Epoch 275/500
# 7/7 [==============================] - 0s 862us/step - loss: 0.1057
# Epoch 276/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.1053
# Epoch 277/500
# 7/7 [==============================] - 0s 823us/step - loss: 0.1048
# Epoch 278/500
# 7/7 [==============================] - 0s 668us/step - loss: 0.1043
# Epoch 279/500
# 7/7 [==============================] - 0s 586us/step - loss: 0.1038
# Epoch 280/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1034
# Epoch 281/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1029
# Epoch 282/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.1025
# Epoch 283/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.1020
# Epoch 284/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1017
# Epoch 285/500
# 7/7 [==============================] - 0s 861us/step - loss: 0.1012
# Epoch 286/500
# 7/7 [==============================] - 0s 999us/step - loss: 0.1007
# Epoch 287/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1003
# Epoch 288/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0999
# Epoch 289/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0995
# Epoch 290/500
# 7/7 [==============================] - 0s 949us/step - loss: 0.0990
# Epoch 291/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0986
# Epoch 292/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0982
# Epoch 293/500
# 7/7 [==============================] - 0s 953us/step - loss: 0.0978
# Epoch 294/500
# 7/7 [==============================] - 0s 982us/step - loss: 0.0974
# Epoch 295/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0970
# Epoch 296/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0966
# Epoch 297/500
# 7/7 [==============================] - 0s 959us/step - loss: 0.0962
# Epoch 298/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0958
# Epoch 299/500
# 7/7 [==============================] - 0s 997us/step - loss: 0.0954
# Epoch 300/500
# 7/7 [==============================] - 0s 999us/step - loss: 0.0950
# Epoch 301/500
# 7/7 [==============================] - 0s 994us/step - loss: 0.0946
# Epoch 302/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0942
# Epoch 303/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0939
# Epoch 304/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0934
# Epoch 305/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0931
# Epoch 306/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0927
# Epoch 307/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0923
# Epoch 308/500
# 7/7 [==============================] - 0s 810us/step - loss: 0.0920
# Epoch 309/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.0916
# Epoch 310/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0913
# Epoch 311/500
# 7/7 [==============================] - 0s 825us/step - loss: 0.0909
# Epoch 312/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0906
# Epoch 313/500
# 7/7 [==============================] - 0s 798us/step - loss: 0.0902
# Epoch 314/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.0898
# Epoch 315/500
# 7/7 [==============================] - 0s 835us/step - loss: 0.0895
# Epoch 316/500
# 7/7 [==============================] - 0s 757us/step - loss: 0.0892
# Epoch 317/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0888
# Epoch 318/500
# 7/7 [==============================] - 0s 682us/step - loss: 0.0885
# Epoch 319/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0881
# Epoch 320/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.0877
# Epoch 321/500
# 7/7 [==============================] - 0s 934us/step - loss: 0.0874
# Epoch 322/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0871
# Epoch 323/500
# 7/7 [==============================] - 0s 893us/step - loss: 0.0868
# Epoch 324/500
# 7/7 [==============================] - 0s 912us/step - loss: 0.0865
# Epoch 325/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0861
# Epoch 326/500
# 7/7 [==============================] - 0s 789us/step - loss: 0.0858
# Epoch 327/500
# 7/7 [==============================] - 0s 676us/step - loss: 0.0855
# Epoch 328/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0852
# Epoch 329/500
# 7/7 [==============================] - 0s 771us/step - loss: 0.0849
# Epoch 330/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0846
# Epoch 331/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.0843
# Epoch 332/500
# 7/7 [==============================] - 0s 776us/step - loss: 0.0839
# Epoch 333/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0836
# Epoch 334/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0833
# Epoch 335/500
# 7/7 [==============================] - 0s 954us/step - loss: 0.0830
# Epoch 336/500
# 7/7 [==============================] - 0s 952us/step - loss: 0.0827
# Epoch 337/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0824
# Epoch 338/500
# 7/7 [==============================] - 0s 920us/step - loss: 0.0821
# Epoch 339/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0818
# Epoch 340/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0815
# Epoch 341/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0812
# Epoch 342/500
# 7/7 [==============================] - 0s 858us/step - loss: 0.0810
# Epoch 343/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0806
# Epoch 344/500
# 7/7 [==============================] - 0s 921us/step - loss: 0.0804
# Epoch 345/500
# 7/7 [==============================] - 0s 957us/step - loss: 0.0801
# Epoch 346/500
# 7/7 [==============================] - 0s 817us/step - loss: 0.0798
# Epoch 347/500
# 7/7 [==============================] - 0s 824us/step - loss: 0.0795
# Epoch 348/500
# 7/7 [==============================] - 0s 970us/step - loss: 0.0793
# Epoch 349/500
# 7/7 [==============================] - 0s 887us/step - loss: 0.0790
# Epoch 350/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0787
# Epoch 351/500
# 7/7 [==============================] - 0s 755us/step - loss: 0.0784
# Epoch 352/500
# 7/7 [==============================] - 0s 677us/step - loss: 0.0782
# Epoch 353/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0780
# Epoch 354/500
# 7/7 [==============================] - 0s 686us/step - loss: 0.0776
# Epoch 355/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0774
# Epoch 356/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0771
# Epoch 357/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0768
# Epoch 358/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0766
# Epoch 359/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0763
# Epoch 360/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0761
# Epoch 361/500
# 7/7 [==============================] - 0s 993us/step - loss: 0.0758
# Epoch 362/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0755
# Epoch 363/500
# 7/7 [==============================] - 0s 862us/step - loss: 0.0753
# Epoch 364/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0750
# Epoch 365/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0748
# Epoch 366/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0745
# Epoch 367/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0743
# Epoch 368/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0741
# Epoch 369/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0738
# Epoch 370/500
# 7/7 [==============================] - 0s 910us/step - loss: 0.0736
# Epoch 371/500
# 7/7 [==============================] - 0s 900us/step - loss: 0.0734
# Epoch 372/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0731
# Epoch 373/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0728
# Epoch 374/500
# 7/7 [==============================] - 0s 817us/step - loss: 0.0726
# Epoch 375/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0724
# Epoch 376/500
# 7/7 [==============================] - 0s 847us/step - loss: 0.0721
# Epoch 377/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.0719
# Epoch 378/500
# 7/7 [==============================] - 0s 832us/step - loss: 0.0717
# Epoch 379/500
# 7/7 [==============================] - 0s 847us/step - loss: 0.0715
# Epoch 380/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0712
# Epoch 381/500
# 7/7 [==============================] - 0s 807us/step - loss: 0.0710
# Epoch 382/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0708
# Epoch 383/500
# 7/7 [==============================] - 0s 861us/step - loss: 0.0706
# Epoch 384/500
# 7/7 [==============================] - 0s 500us/step - loss: 0.0703
# Epoch 385/500
# 7/7 [==============================] - 0s 893us/step - loss: 0.0701
# Epoch 386/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0699
# Epoch 387/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0697
# Epoch 388/500
# 7/7 [==============================] - 0s 755us/step - loss: 0.0695
# Epoch 389/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0692
# Epoch 390/500
# 7/7 [==============================] - 0s 682us/step - loss: 0.0690
# Epoch 391/500
# 7/7 [==============================] - 0s 668us/step - loss: 0.0688
# Epoch 392/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0686
# Epoch 393/500
# 7/7 [==============================] - 0s 759us/step - loss: 0.0684
# Epoch 394/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0682
# Epoch 395/500
# 7/7 [==============================] - 0s 686us/step - loss: 0.0680
# Epoch 396/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.0678
# Epoch 397/500
# 7/7 [==============================] - 0s 700us/step - loss: 0.0676
# Epoch 398/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0674
# Epoch 399/500
# 7/7 [==============================] - 0s 978us/step - loss: 0.0672
# Epoch 400/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0670
# Epoch 401/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0668
# Epoch 402/500
# 7/7 [==============================] - 0s 751us/step - loss: 0.0666
# Epoch 403/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0664
# Epoch 404/500
# 7/7 [==============================] - 0s 800us/step - loss: 0.0661
# Epoch 405/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0660
# Epoch 406/500
# 7/7 [==============================] - 0s 823us/step - loss: 0.0658
# Epoch 407/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0656
# Epoch 408/500
# 7/7 [==============================] - 0s 874us/step - loss: 0.0654
# Epoch 409/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0651
# Epoch 410/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0650
# Epoch 411/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0648
# Epoch 412/500
# 7/7 [==============================] - 0s 931us/step - loss: 0.0646
# Epoch 413/500
# 7/7 [==============================] - 0s 830us/step - loss: 0.0644
# Epoch 414/500
# 7/7 [==============================] - 0s 865us/step - loss: 0.0642
# Epoch 415/500
# 7/7 [==============================] - 0s 774us/step - loss: 0.0640
# Epoch 416/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0639
# Epoch 417/500
# 7/7 [==============================] - 0s 735us/step - loss: 0.0637
# Epoch 418/500
# 7/7 [==============================] - 0s 839us/step - loss: 0.0635
# Epoch 419/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.0633
# Epoch 420/500
# 7/7 [==============================] - 0s 832us/step - loss: 0.0631
# Epoch 421/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.0629
# Epoch 422/500
# 7/7 [==============================] - 0s 674us/step - loss: 0.0628
# Epoch 423/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0626
# Epoch 424/500
# 7/7 [==============================] - 0s 786us/step - loss: 0.0624
# Epoch 425/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0622
# Epoch 426/500
# 7/7 [==============================] - 0s 675us/step - loss: 0.0621
# Epoch 427/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0619
# Epoch 428/500
# 7/7 [==============================] - 0s 841us/step - loss: 0.0617
# Epoch 429/500
# 7/7 [==============================] - 0s 998us/step - loss: 0.0615
# Epoch 430/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0614
# Epoch 431/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0612
# Epoch 432/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0610
# Epoch 433/500
# 7/7 [==============================] - 0s 957us/step - loss: 0.0609
# Epoch 434/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0607
# Epoch 435/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0605
# Epoch 436/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0604
# Epoch 437/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0602
# Epoch 438/500
# 7/7 [==============================] - 0s 998us/step - loss: 0.0600
# Epoch 439/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.0599
# Epoch 440/500
# 7/7 [==============================] - 0s 920us/step - loss: 0.0597
# Epoch 441/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0595
# Epoch 442/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0594
# Epoch 443/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0592
# Epoch 444/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0591
# Epoch 445/500
# 7/7 [==============================] - 0s 844us/step - loss: 0.0589
# Epoch 446/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0587
# Epoch 447/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0586
# Epoch 448/500
# 7/7 [==============================] - 0s 668us/step - loss: 0.0585
# Epoch 449/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0583
# Epoch 450/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.0581
# Epoch 451/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.0580
# Epoch 452/500
# 7/7 [==============================] - 0s 922us/step - loss: 0.0578
# Epoch 453/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0577
# Epoch 454/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 455/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0574
# Epoch 456/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0572
# Epoch 457/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0571
# Epoch 458/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0569
# Epoch 459/500
# 7/7 [==============================] - 0s 747us/step - loss: 0.0568
# Epoch 460/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0566
# Epoch 461/500
# 7/7 [==============================] - 0s 835us/step - loss: 0.0565
# Epoch 462/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.0563
# Epoch 463/500
# 7/7 [==============================] - 0s 861us/step - loss: 0.0562
# Epoch 464/500
# 7/7 [==============================] - 0s 666us/step - loss: 0.0561
# Epoch 465/500
# 7/7 [==============================] - 0s 674us/step - loss: 0.0559
# Epoch 466/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0558
# Epoch 467/500
# 7/7 [==============================] - 0s 667us/step - loss: 0.0556
# Epoch 468/500
# 7/7 [==============================] - 0s 752us/step - loss: 0.0555
# Epoch 469/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0553
# Epoch 470/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0552
# Epoch 471/500
# 7/7 [==============================] - 0s 955us/step - loss: 0.0550
# Epoch 472/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0549
# Epoch 473/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0548
# Epoch 474/500
# 7/7 [==============================] - 0s 918us/step - loss: 0.0546
# Epoch 475/500
# 7/7 [==============================] - 0s 852us/step - loss: 0.0545
# Epoch 476/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0543
# Epoch 477/500
# 7/7 [==============================] - 0s 905us/step - loss: 0.0542
# Epoch 478/500
# 7/7 [==============================] - 0s 836us/step - loss: 0.0541
# Epoch 479/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0539
# Epoch 480/500
# 7/7 [==============================] - 0s 867us/step - loss: 0.0538
# Epoch 481/500
# 7/7 [==============================] - 0s 944us/step - loss: 0.0537
# Epoch 482/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0536
# Epoch 483/500
# 7/7 [==============================] - 0s 883us/step - loss: 0.0534
# Epoch 484/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0533
# Epoch 485/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0532
# Epoch 486/500
# 7/7 [==============================] - 0s 753us/step - loss: 0.0531
# Epoch 487/500
# 7/7 [==============================] - 0s 834us/step - loss: 0.0529
# Epoch 488/500
# 7/7 [==============================] - 0s 935us/step - loss: 0.0528
# Epoch 489/500
# 7/7 [==============================] - 0s 922us/step - loss: 0.0527
# Epoch 490/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0525
# Epoch 491/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0524
# Epoch 492/500
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0523
# Epoch 493/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0522
# Epoch 494/500
# 7/7 [==============================] - 0s 1000us/step - loss: 0.0520
# Epoch 495/500
# 7/7 [==============================] - 0s 964us/step - loss: 0.0519
# Epoch 496/500
# 7/7 [==============================] - 0s 919us/step - loss: 0.0518
# Epoch 497/500
# 7/7 [==============================] - 0s 833us/step - loss: 0.0517
# Epoch 498/500
# 7/7 [==============================] - 0s 838us/step - loss: 0.0515
# Epoch 499/500
# 7/7 [==============================] - 0s 664us/step - loss: 0.0514
# Epoch 500/500
# 7/7 [==============================] - 0s 830us/step - loss: 0.0513

# %%
# Hiển thị loss theo số epoch
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Sau khi đã huấn luyện, ta lưu mô hình về để sau này tái sử dụng
# Lưu ý: hai phương thức lưu mô hình `save` và tải mô hình lên 'load'
# được sử dụng khi muốn tái sử dụng nhiều lần mà KHÔNG CẦN PHẢI HUẤN LUYỆN LẠI
nn.save('neural_network_model.h5')

# %% [markdown]
# ## 5. Trực quan hóa mô hình và dự đoán với dữ liệu test

# %%
# Khởi tạo đối tượng mới và gọi phương thức load mô hình từ file
pretrain_nn = NeuralNetwork()
pretrain_nn.load('neural_network_model.h5')

# %%
# In ra bộ tham số tối ưu lớp cuối cùng
theta = pretrain_nn.get_weights(-1)
print('Tham số tối ưu: ')
print(theta)
# Out:
# Tham số tối ưu:
# [array([[ 4.081455 , -2.6661363, -3.426687 ,  1.0761319],
#        [-2.6426616,  3.2064028, -3.9796202,  1.3164175],
#        [-1.4048568, -2.0825627, -0.5660519,  4.1269093]], dtype=float32), array([-0.61914974, -0.25852212,  3.0081315 , -2.1304653 ], dtype=float32)]

# %%
# Trực quan hóa dữ liệu và mô hình sau khi huấn luyện
# Ý tưởng: lấy mẫu dày đặc các điểm trong phạm vi dữ liệu train
# Sau đó dùng mô hình để dự đoán và hiển thị kết quả

# `colors` là các marker được sử dụng để trực quan hóa kết quả test
colors = ['r+', 'g+', 'b+', 'y+']
# `gt_colors` là các marker được sử dụng để trực quan hóa dữ liệu train
gt_colors = ['ro', 'go', 'bo', 'yo']

# Lấy mẫu dày đặc các điểm
x = np.arange(-8, 17, 1)
y = np.arange(-8, 17, 1)
xx, yy = np.meshgrid(x,y)

xx = xx.reshape(-1)
yy = yy.reshape(-1)

# Tạo các dữ liệu test dày đặc
X_test = np.concatenate([[xx],[yy]], axis=0).T
Y_pred = pretrain_nn.predict(X_test)

for i in range(len(xx)):
    plt.plot(xx[i],yy[i], colors[np.argmax(Y_pred[i])])
plt.plot(pts1[:,0], pts1[:,1], gt_colors[0])
plt.plot(pts2[:,0], pts2[:,1], gt_colors[1])
plt.plot(pts3[:,0], pts3[:,1], gt_colors[2])
plt.plot(pts4[:,0], pts4[:,1], gt_colors[3])
plt.show()
# Out:
# 20/20 [==============================] - 0s 589us/step

# %% [markdown]
# Ta có thể thấy rằng, không gian mặt phẳng đã được phân loại sử dụng mô hình Neural Network đã huấn luyện trước đó. Dựa trên hình trên ta thấy kết quả khá chính xác, chỉ trừ một số điểm ở biên giữa các lớp.

# %% [markdown]
# ## 6. Thử nghiệm với tập dữ liệu  MNIST
#
# MNIST là tập dữ liệu chữ số viết tay kinh điển trong lĩnh vực máy học. Để tải và sử dụng dữ liệu này cực kỳ đơn giản chỉ với 2 dòng code:

# %%
# Prepare MNIST dataset
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# Để hiểu rõ hơn về dữ liệu này, ta sẽ trực quan hóa dữ liệu bằng cách hiển thị ảnh và xem kích thước ảnh.

# %%
plt.imshow(x_train[1234])
print('Nhãn của mẫu dữ liệu thứ 1234: ', y_train[1234])
print('Kích thước của ảnh train: ', x_train[1234].shape)
print('Số điểm ảnh nếu biến đổi thành vector: ', 
      x_train[1234].shape[0]*x_train[1234].shape[1])
# Out:
# Nhãn của mẫu dữ liệu thứ 1234:  3
# Kích thước của ảnh train:  (28, 28)
# Số điểm ảnh nếu biến đổi thành vector:  784

# %% [markdown]
# Tiền xử lý dữ liệu trước khi huấn luyện mô hình:
# - Chuyển output sang dạng one-hot vector
# - Chuẩn hóa dữ liệu input về khoảng giá trị `[0-1]`

# %%
# Hàm chuyển đổi output từ dạng nhãn (label) sang vector one-hot
def onehot(y):
    oh = np.zeros((y.shape[0], y.max()+1))
    oh[np.arange(y.shape[0]), y] = 1
    return oh

y_train_oh = onehot(y_train)
y_test_oh = onehot(y_test)

# Chuẩn hóa dữ liệu input trên dữ liệu train và test
n_train_sample, h, w = x_train.shape
n_test_sample, _,_ = x_test.shape # Kích thước ngang x cao giống nhau trên tất cả mẫu

x_train = (x_train.astype('float32')) / 255.0
x_test = (x_test.astype('float32')) / 255.0
x_train_vec = x_train.reshape((n_train_sample, w*h))
x_test_vec = x_test.reshape((n_test_sample, w*h))
# Out:
# (60000, 784)

# %% [markdown]
# Khởi tạo mô hình từ đầu sao cho phù hợp với dữ liệu MNIST.
# Trong đó, thông tin cấu hình về lớp ẩn:
# - 2 lớp ẩn
# - 100 neuron mỗi lớp ẩn
# - huấn luyện với 30 epochs

# %%
nn4mnist = NeuralNetwork()

# Hoàn tất đoạn code sau đây với việc sử dụng biến `nn4mnist` để gọi
# phương thức `build`# và `train`. Lưu ý: sử dụng các tham số phù hợp
# theo yêu cầu đã nêu.

# YOUR CODE HERE
input_dim = 28 * 28
output_dim = 10
n_hidden = 2
n_neurons = 100
epoch = 30

#build
nn4mnist.build(input_dim, output_dim, n_hidden, n_neurons)

#train
hist = nn4mnist.train(x_train_vec, y_train_oh, epochs=epoch)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 2s 919us/step - loss: 2.3110
# Epoch 2/30
# 1875/1875 [==============================] - 2s 893us/step - loss: 2.3093
# Epoch 3/30
# 1875/1875 [==============================] - 2s 905us/step - loss: 2.3079
# Epoch 4/30
# 1875/1875 [==============================] - 2s 885us/step - loss: 2.3065
# Epoch 5/30
# 1875/1875 [==============================] - 2s 989us/step - loss: 2.3059
# Epoch 6/30
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.3053
# Epoch 7/30
# 1875/1875 [==============================] - 2s 977us/step - loss: 2.3047
# Epoch 8/30
# 1875/1875 [==============================] - 2s 910us/step - loss: 2.3041
# Epoch 9/30
# 1875/1875 [==============================] - 2s 947us/step - loss: 2.3037
# Epoch 10/30
# 1875/1875 [==============================] - 2s 872us/step - loss: 2.3034
# Epoch 11/30
# 1875/1875 [==============================] - 2s 918us/step - loss: 2.3034
# Epoch 12/30
# 1875/1875 [==============================] - 2s 886us/step - loss: 2.3032
# Epoch 13/30
# 1875/1875 [==============================] - 2s 905us/step - loss: 2.3030
# Epoch 14/30
# 1875/1875 [==============================] - 2s 921us/step - loss: 2.3029
# Epoch 15/30
# 1875/1875 [==============================] - 2s 920us/step - loss: 2.3028
# Epoch 16/30
# 1875/1875 [==============================] - 2s 942us/step - loss: 2.3029
# Epoch 17/30
# 1875/1875 [==============================] - 2s 923us/step - loss: 2.3026
# Epoch 18/30
# 1875/1875 [==============================] - 2s 922us/step - loss: 2.3023
# Epoch 19/30
# 1875/1875 [==============================] - 2s 898us/step - loss: 2.3025
# Epoch 20/30
# 1875/1875 [==============================] - 2s 885us/step - loss: 2.3024
# Epoch 21/30
# 1875/1875 [==============================] - 2s 906us/step - loss: 2.3025
# Epoch 22/30
# 1875/1875 [==============================] - 2s 930us/step - loss: 2.3022
# Epoch 23/30
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.3022
# Epoch 24/30
# 1875/1875 [==============================] - 2s 971us/step - loss: 2.3021
# Epoch 25/30
# 1875/1875 [==============================] - 2s 941us/step - loss: 2.3021
# Epoch 26/30
# 1875/1875 [==============================] - 2s 931us/step - loss: 2.3021
# Epoch 27/30
# 1875/1875 [==============================] - 2s 943us/step - loss: 2.3021
# Epoch 28/30
# 1875/1875 [==============================] - 2s 965us/step - loss: 2.3021
# Epoch 29/30
# 1875/1875 [==============================] - 2s 927us/step - loss: 2.3020
# Epoch 30/30
# 1875/1875 [==============================] - 2s 904us/step - loss: 2.3020

# %%
# Trực quan hóa giá trị loss trong quá trình huấn luyện
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Kiểm tra sơ bộ biến `hist`: nếu quá trình khởi tạo và huấn luyện thành công
# thì các bài test sau sẽ vượt qua được.
assert hist is not None
assert 'loss' in hist.history
assert len(hist.history['loss']) == 30

# %%
# Kiểm tra với bộ test ẩn

# %% [markdown]
# Sau quá trình huấn luyện, chúng ta sử dụng mô hình để dự đoán trên mẫu dữ liệu test:

# %%
pred = nn4mnist.predict(x_test_vec)
# Out:
# 313/313 [==============================] - 0s 750us/step

# %% [markdown]
# Cuối cùng, trực quan hóa một mẫu dữ liệu test bất kỳ (ví dụ mẫu thứ 50):

# %%
# Show the 50-th test sample
test_id = 50
plt.imshow(x_test[test_id])
print('Label of the data: ', y_test[test_id])
print('Predicted label of the data: ', np.argmax(pred[test_id]))
# Out:
# Label of the data:  6
# Predicted label of the data:  1
